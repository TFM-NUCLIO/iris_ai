# %%
import pickle
import os
import torch

# %%
with open('./IrisAutoencoder_Pytorch/train_data/X3D.pkl', 'rb') as f:
    X3D = pickle.load(f)

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.6180, 0.4235, 0.8222],
#         [0.9909, 0.1650, 0.1126],
#         [0.3787, 0.3958, 0.9352],
#         [0.7271, 0.0982, 0.7146],
#         [0.2861, 0.7748, 0.1115]])

# %%
    X3D
# Out:
# <xarray.DataArray (measurement: 3, dim_0: 55605, dim_1: 312)>
# array([[[5.15092202e-06, 1.15895745e-05, 2.10150625e-05, ...,
#                     nan,            nan,            nan],
#         [1.49376738e-04, 1.40362625e-04, 2.39921964e-04, ...,
#                     nan,            nan,            nan],
#         [1.54527660e-05, 2.18914186e-05, 7.00502085e-06, ...,
#                     nan,            nan,            nan],
#         ...,
#         [9.91552488e-05, 7.98392912e-05, 1.34846651e-04, ...,
#                     nan,            nan,            nan],
#         [1.98310498e-04, 1.66117235e-04, 2.97713386e-04, ...,
#                     nan,            nan,            nan],
#         [2.04362831e-03, 2.04362831e-03, 2.77924202e-03, ...,
#                     nan,            nan,            nan]],
#
#        [[2.00147277e-04, 3.03461304e-04, 1.60795217e-04, ...,
#                     nan,            nan,            nan],
# ...
